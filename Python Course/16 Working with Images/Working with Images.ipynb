# %%
from PIL import Image

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '01-Image-Exercise.ipynb',
#  'blue_color.png',
#  'example.jpg',
#  'mask.png',
#  'pencils.jpg',
#  'purple.png',
#  'red_color.jpg',
#  'word_matrix.png',
#  'Working with Images.ipynb']

# %%
mac = Image.open("example.jpg")

# %%
mac.show() # function to use when not working with jupyter notebooks to view image

# %%
type(mac)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257>

# %%
mac.size
# Out:
# (1993, 1257)

# %%
mac.crop((0,0,1000,600))
# Out:
# <PIL.Image.Image image mode=RGB size=1000x600>

# %%
pencil = Image.open("pencils.jpg")

# %%
x = 0
y = 0
w = 1950/3
h = 1300/10
pencil.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=650x130>

# %%
computer = mac.crop((800, 800, 1230, 1257))

# %%
computer.size
# Out:
# (430, 457)

# %%
mac.paste(im=computer,box=(0,800))

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257>

# %%
mac.paste(im=computer, box=(1993-430,800))

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257>

# %%
red = Image.open("red_color.jpg")

# %%
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200>

# %%
red.size
# Out:
# (200, 200)

# %%
blue = Image.open("blue_color.png")

# %%
blue
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=200x200>

# %%
blue.size
# Out:
# (200, 200)

# %%
red.putalpha(128)

# %%
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=200x200>

# %%
blue.putalpha(128)

# %%
blue
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=PA size=200x200>

# %%
red.paste(im=blue, box=(0,0))

# %%
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=200x200>

# %%
red.save("new_color.png")

# %%
new_color = Image.open("new_color.png")

# %%
new_color
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=200x200>
